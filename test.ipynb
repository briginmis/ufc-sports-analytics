# %%
import pandas as pd

# %%
fighters = pd.read_csv("resources/goat_data.csv", index_col = 0)

# %%
fighters
# Out:
#                           date  wins  losses  draw  current_lose_streak  \
# name
# Aalon Cruz          2021-03-06     1       1     0                    1
# Aaron Phillips      2020-07-15     0       2     0                    2
# Aaron Riley         2013-07-27     3       5     0                    1
# Aaron Rosa          2012-03-02     1       1     0                    0
# Aaron Simpson       2012-10-05     7       3     0                    0
# ...                        ...   ...     ...   ...                  ...
# Zhalgas Zhamagulov  2020-07-11     0       0     0                    0
# Zhalgas Zhumagulov  2021-07-10     0       2     0                    2
# Zhang Lipeng        2015-05-16     2       1     0                    1
# Zhang Weili         2021-04-24     5       0     0                    0
# Zubaira Tukhugov    2020-09-26     4       1     1                    0
#
#                     current_win_streak  avg_SIG_STR_landed  avg_SIG_STR_pct  \
# name
# ...

# %%
from sqlalchemy import create_engine, func
engine = create_engine("sqlite:///resources/fighter_data.sqlite")

# %%
df = pd.read_sql('select * from goat_data',engine)

# %%
df
df = df.drop(["date", "winratio"], axis = 1)

# %%
df_selected_fighter1 = df.loc[df["name"] == "Conor McGregor"]
df_selected_fighter2 = df.loc[df["name"] == "Khabib Nurmagomedov"]
df_selected_fighter1
# Out:
#                name  wins  losses  draw  current_lose_streak  \
# 304  Conor McGregor    10       3     0                    1
#
#      current_win_streak  avg_SIG_STR_landed  avg_SIG_STR_pct  avg_SUB_ATT  \
# 304                   0                5.32             0.49          0.1
#
#      avg_TD_landed  ...  total_rounds_fought  total_title_bouts  \
# 304           0.67  ...                   27                  4
#
#      win_by_Decision_Majority  win_by_Decision_Split  \
# 304                         1                      0
#
#      win_by_Decision_Unanimous  win_by_KO/TKO  win_by_Submission  \
# 304                          1              8                  0
#
#      win_by_TKO_DoctoStoppage  age    Stance
# 304                         0   32  Southpaw
#
# [1 rows x 22 columns]

# %%
from prediction import predict, clean_cols

# %%
clean_cols(df_selected_fighter1,df_selected_fighter2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38312/465530566.py in <module>
# ----> 1 clean_cols(df_selected_fighter1,df_selected_fighter2)
#
# c:\Users\brian\OneDrive\Documents\Data_analytics_bootcamp\Project_3\project3-ufc\prediction.py in clean_cols(fighter1, fighter2)
#      92
#      93     fighter1 = fighter1[new_column_list]
# ---> 94     fighter1 = fighter1.rename(columns = B_col_replace)
#      95     fighter1 = fighter1.drop("B_fighter", axis = 1)
#      96     fighter2 = fighter2[new_column_list]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
    B_column_list = ["B_fighter",
                    "B_wins",
                    "B_losses",
                    "B_draw",
                    "B_current_lose_streak",
                    "B_current_win_streak",
                    "B_avg_SIG_STR_landed",
                    "B_avg_SIG_STR_pct",
                    "B_avg_SUB_ATT",
                    "B_avg_TD_landed",
                    "B_avg_TD_pct",
                    "B_longest_win_streak",
                    "B_total_rounds_fought",
                    "B_total_title_bouts",
                    "B_win_by_Decision_Majority",
                    "B_win_by_Decision_Split",
                    "B_win_by_Decision_Unanimous",
                    "B_win_by_KO/TKO",
                    "B_win_by_Submission",
                    "B_win_by_TKO_Doctor_Stoppage",
                    "B_age",
                    "B_Stance"
                    ]

    R_column_list = ["R_fighter",
                    "R_wins",
                    "R_losses",
                    "R_draw",
                    "R_current_lose_streak",
                    "R_current_win_streak",
                    "R_avg_SIG_STR_landed",
                    "R_avg_SIG_STR_pct",
                    "R_avg_SUB_ATT",
                    "R_avg_TD_landed",
                    "R_avg_TD_pct",
                    "R_longest_win_streak",
                    "R_total_rounds_fought",
                    "R_total_title_bouts",
                    "R_win_by_Decision_Majority",
                    "R_win_by_Decision_Split",
                    "R_win_by_Decision_Unanimous",
                    "R_win_by_KO/TKO",
                    "R_win_by_Submission",
                    "R_win_by_TKO_Doctor_Stoppage",
                    "R_age",
                    "R_Stance"
                    ]

    new_column_list = ["name",
                    "wins",
                    "losses",
                    "draw",
                    "current_lose_streak",
                    "current_win_streak",
                    "avg_SIG_STR_landed",
                    "avg_SIG_STR_pct",
                    "avg_SUB_ATT",
                    "avg_TD_landed",
                    "avg_TD_pct",
                    "longest_win_streak",
                    "total_rounds_fought",
                    "total_title_bouts",
                    "win_by_Decision_Majority",
                    "win_by_Decision_Split",
                    "win_by_Decision_Unanimous",
                    "win_by_KO/TKO",
                    "win_by_Submission",
                    "win_by_TKO_DoctoStoppage",
                    "age",
                    "Stance"
                    ]
    
    R_col_replace = {}
    B_col_replace = {}
    R_count = 0
    B_count = 0

    for header in new_column_list:
        R_col_replace[header] = R_column_list[R_count]
        R_count +=1

    for header in new_column_list:
        B_col_replace[header] = B_column_list[B_count]
        B_count +=1

    df_selected_fighter1 = df_selected_fighter1[new_column_list]
    df_selected_fighter1 = df_selected_fighter1.rename(columns = B_col_replace)
    df_selected_fighter1 = df_selected_fighter1.drop("B_fighter", axis = 1)
    df_selected_fighter2 = df_selected_fighter2[new_column_list]
    df_selected_fighter2 = df_selected_fighter2.rename(columns = R_col_replace)
    df_selected_fighter2 = df_selected_fighter2.drop("R_fighter", axis = 1)

# %%
df_selected_fighter1
# Out:
#      B_wins  B_losses  B_draw  B_current_lose_streak  B_current_win_streak  \
# 304      10         3       0                      1                     0
#
#      B_avg_SIG_STR_landed  B_avg_SIG_STR_pct  B_avg_SUB_ATT  B_avg_TD_landed  \
# 304                  5.32               0.49            0.1             0.67
#
#      B_avg_TD_pct  ...  B_total_rounds_fought  B_total_title_bouts  \
# 304          0.55  ...                     27                    4
#
#      B_win_by_Decision_Majority  B_win_by_Decision_Split  \
# 304                           1                        0
#
#      B_win_by_Decision_Unanimous  B_win_by_KO/TKO  B_win_by_Submission  \
# 304                            1                8                    0
#
#      B_win_by_TKO_Doctor_Stoppage  B_age  B_Stance
# 304                             0     32  Southpaw
#
# [1 rows x 21 columns]

# %%
df_selected_fighter2
# Out:
#      R_wins  R_losses  R_draw  R_current_lose_streak  R_current_win_streak  \
# 865      12         0       0                      0                    12
#
#      R_avg_SIG_STR_landed  R_avg_SIG_STR_pct  R_avg_SUB_ATT  R_avg_TD_landed  \
# 865                  4.11               0.49            0.7             5.35
#
#      R_avg_TD_pct  ...  R_total_rounds_fought  R_total_title_bouts  \
# 865          0.47  ...                     36                    3
#
#      R_win_by_Decision_Majority  R_win_by_Decision_Split  \
# 865                           0                        0
#
#      R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 865                            6                2                    4
#
#      R_win_by_TKO_Doctor_Stoppage  R_age  R_Stance
# 865                             0     32  Orthodox
#
# [1 rows x 21 columns]
